# %%
import pandas as pd 
import numpy as np
scores_math_path="./training_data/2020年第八届逻辑推理大赛成绩.xlsx"
scores_soil_path="./training_data/各组评分 土壤肥科学.xlsx"
scores_math_data=pd.read_excel(scores_math_path,header=1,dtype="object")
scores_soil_data=pd.read_excel(scores_soil_path)

# %%
scores_math_data
# Out:
#      姓名            班级         联系方式   一     二    三    总分
# 0   毛译轩           NaN          NaN  25    20   30    75
# 1    刘犇         动科院动科  15111216188  20  22.5   30  72.5
# 2   旷静泉      经济学院投资一班  13203051209  30    20   22    72
# 3   陈博文         互联网二班  15073717795  25  22.5   20  67.5
# 4   陈志明         植保院生信  17346936486  30    20   17    67
# 5   毛昊宇           信科院  17872779327  25    20   22    67
# 6    杨宇           NaN          NaN  25    15   25    65
# 7   骆佳庆    机电工程学院机械8班  17374642107  25    25   15    65
# 8   邱诗烜         资环院生态  18039800110  30    20   15    65
# 9   汤帅兰           商学院  18774868786  30  17.5   15  62.5
# 10  王尉成      水利土木安全工程  18573643690  25  17.5   19  61.5
# 11  曹芷熙        经济学院农经  13647488662  30    10   20    60
# 12  马涵迪           NaN          NaN  25    15   20    60
# 13   张宇     动科院动物科学一班  17369356375  30    15   14    59
# 14  谢潇伊       信科院统计二班  15367619186  25    20   12    57
# 15  李承奇          电信三班  15387354605  25  17.5   14  56.5
# ...
